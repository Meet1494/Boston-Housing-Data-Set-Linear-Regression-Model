# %% [markdown]
# <a href="https://colab.research.google.com/gist/Meet1494/7ad8a344aebd5abc2a665676a26ae64b/boston-housing-ml-linear-regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/housing.csv')

# %%
df
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %%
df.describe()
# Out:
#                RM       LSTAT     PTRATIO          MEDV
# count  489.000000  489.000000  489.000000  4.890000e+02
# mean     6.240288   12.939632   18.516564  4.543429e+05
# std      0.643650    7.081990    2.111268  1.653403e+05
# min      3.561000    1.980000   12.600000  1.050000e+05
# 25%      5.880000    7.370000   17.400000  3.507000e+05
# 50%      6.185000   11.690000   19.100000  4.389000e+05
# 75%      6.575000   17.120000   20.200000  5.187000e+05
# max      8.398000   37.970000   22.000000  1.024800e+06

# %%
df

# %%
from sklearn import preprocessing

# %%
df.columns = [col.strip() for col in df.columns]
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
y=df["MEDV"]
X=df.drop(["MEDV"],axis='columns')
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
Model = LinearRegression()
Model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = Model.predict(X_test)
print(f"Mean Squared Error = {metrics.mean_squared_error(y_test,y_pred)}")
# Out:
# Mean Squared Error = 7048219280.21769

# %%
def pipeline(datapoint):
  print(f"The estimated MEDV = {Model.predict(datapoint)[0]}")
  return Model.predict(datapoint)[0]

# %%
y_test.head(1)
# Out:
# 451    401100.0
# Name: MEDV, dtype: float64

# %%
Predicted_median = pipeline(X_test[:1])
# Out:
# The estimated MEDV = 344506.4875906071
